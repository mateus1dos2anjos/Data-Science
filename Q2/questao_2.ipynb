# %%
import glob
import os
import pandas as pd
import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error
# from math import sqrt
import matplotlib.pyplot as plt

# %%
all_files = glob.glob(os.path.join("data", "*.csv"))
dataframe = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
dataframe
# Out:
#         ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 0         2018     4590      4590/2018  31/12/2018 23:55:04
# 1         2018     8741      8741/2018  31/12/2018 23:50:15
# 2         2018     3396      3396/2018  31/12/2018 23:46:32
# 3         2018     5767      5767/2018  31/12/2018 23:52:58
# 4         2018    12332     12332/2018  31/12/2018 23:57:00
# ...        ...      ...            ...                  ...
# 120549    2019     8392      8392/2019  30/09/2019 20:41:37
# 120550    2019     8392      8392/2019  30/09/2019 20:41:37
# 120551    2019     7285      7285/2019  30/09/2019 23:33:50
# 120552    2019  1233642   1233642/2019  30/09/2019 23:57:40
# 120553    2019  1233642   1233642/2019  30/09/2019 23:57:40
#
#                  BO_EMITIDO DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA  \
# 0       01/01/2019 00:04:02     31/12/2018          22:30          A NOITE
# 1       01/01/2019 00:06:43     31/12/2018          23:30          A NOITE
# ...

# %%
dataframe.columns
# Out:
# Index(['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'BO_INICIADO', 'BO_EMITIDO',
#        'DATAOCORRENCIA', 'HORAOCORRENCIA', 'PERIDOOCORRENCIA',
#        'DATACOMUNICACAO', 'DATAELABORACAO', 'BO_AUTORIA', 'FLAGRANTE',
#        'NUMERO_BOLETIM_PRINCIPAL', 'LOGRADOURO', 'NUMERO', 'BAIRRO', 'CIDADE',
#        'UF', 'LATITUDE', 'LONGITUDE', 'DESCRICAOLOCAL', 'EXAME', 'SOLUCAO',
#        'DELEGACIA_NOME', 'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA',
#        'DESDOBRAMENTO', 'STATUS', 'NOMEPESSOA', 'TIPOPESSOA', 'VITIMAFATAL',
#        'RG', 'RG_UF', 'NATURALIDADE', 'NACIONALIDADE', 'SEXO',
#        'DATANASCIMENTO', 'IDADE', 'ESTADOCIVIL', 'PROFISSAO', 'GRAUINSTRUCAO',
#        'CORCUTIS', 'NATUREZAVINCULADA', 'TIPOVINCULO', 'RELACIONAMENTO',
#        'PARENTESCO', 'PLACA_VEICULO', 'UF_VEICULO', 'CIDADE_VEICULO',
#        'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO', 'ANO_FABRICACAO',
#        'ANO_MODELO', 'DESCR_TIPO_VEICULO', 'QUANT_CELULAR', 'MARCA_CELULAR'],
#       dtype='object')

# %%
dataframe = dataframe[['DATAOCORRENCIA', 'HORAOCORRENCIA', 'BAIRRO', 'CIDADE']]

# %%
dataframe.values
# Out:
# array([['31/12/2018', '22:30', 'JD COPACABANA', 'POA'],
#        ['31/12/2018', '23:30', 'VILA CURUCA', 'S.PAULO'],
#        ['31/12/2018', '22:00', 'JARDIM AMANDA', 'HORTOLANDIA'],
#        ...,
#        ['29/09/2019', '13:20', 'ITAIM BIBI', 'S.PAULO'],
#        ['30/09/2019', '20:40', 'PARQUE SÃO VICENTE', 'MAUA'],
#        ['30/09/2019', '20:40', 'PARQUE SÃO VICENTE', 'MAUA']],
#       dtype=object)

# %%
dataframe['DATAOCORRENCIA'].isnull().sum()
# Out:
# 0

# %%
dataframe[dataframe['DATAOCORRENCIA'].str.slice(6, 10) == "1019"]['DATAOCORRENCIA']
# Out:
# 42363    23/01/1019
# 42536    23/01/1019
# 42654    23/01/1019
# 55387    02/03/1019
# 69527    10/04/1019
# Name: DATAOCORRENCIA, dtype: object

# %%
dataframe.loc[42363]['DATAOCORRENCIA'] = "23/01/2019"
dataframe.loc[42536]['DATAOCORRENCIA'] = "23/01/2019"
dataframe.loc[42654]['DATAOCORRENCIA'] = "23/01/2019"
dataframe.loc[55387]['DATAOCORRENCIA'] = "02/03/2019"
dataframe.loc[69527]['DATAOCORRENCIA'] = "10/04/2019"

# %%
dataframe['DATAOCORRENCIA'] = pd.to_datetime(dataframe['DATAOCORRENCIA'])
# Out:
# <ipython-input-10-b8aa0a887ff9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['DATAOCORRENCIA'] = pd.to_datetime(dataframe['DATAOCORRENCIA']) ##

# %%
dataframe
# Out:
#        DATAOCORRENCIA HORAOCORRENCIA              BAIRRO        CIDADE
# 0          2018-12-31          22:30       JD COPACABANA           POA
# 1          2018-12-31          23:30         VILA CURUCA       S.PAULO
# 2          2018-12-31          22:00       JARDIM AMANDA   HORTOLANDIA
# 3          2018-12-31          23:20          GUAIANASES       S.PAULO
# 4          2018-12-31          22:45     VILA RUY NOVAES      CAMPINAS
# ...               ...            ...                 ...           ...
# 120549     2019-09-30          18:49            QUIETUDE  PRAIA GRANDE
# 120550     2019-09-30          18:49            QUIETUDE  PRAIA GRANDE
# 120551     2019-09-29          13:20          ITAIM BIBI       S.PAULO
# 120552     2019-09-30          20:40  PARQUE SÃO VICENTE          MAUA
# 120553     2019-09-30          20:40  PARQUE SÃO VICENTE          MAUA
#
# [120554 rows x 4 columns]

# %%
dataframe.groupby([pd.Grouper(key='DATAOCORRENCIA', freq='D'), 'BAIRRO', 'CIDADE', 'HORAOCORRENCIA']).DATAOCORRENCIA.count()
# Out:
# DATAOCORRENCIA  BAIRRO                             CIDADE               HORAOCORRENCIA
# 1919-08-17      PARQUE UNIVERSITARIO DE VIRACOPOS  CAMPINAS             03:00             2
# 1960-11-08      RUDGE RAMOS                        S.BERNARDO DO CAMPO  05:45             2
# 1974-04-06      VILA ANDRADE                       S.PAULO              23:30             1
# 1974-10-27      CAPAO REDONDO                      S.PAULO              18:30             2
# 1978-02-25      VILA PALMARES                      S.ANDRE              13:00             2
#                                                                                          ..
# 2019-12-31      VILA MATILDE                       S.PAULO              20:30             1
#                                                                         21:00             1
#                 VILA PIRES                         S.ANDRE              12:05             1
# ...

# %%
X = dataframe[['DATAOCORRENCIA', 'HORAOCORRENCIA', 'BAIRRO', 'CIDADE']]
# y = dataframe['']

# %%
X
# Out:
#        DATAOCORRENCIA HORAOCORRENCIA              BAIRRO        CIDADE
# 0          2018-12-31          22:30       JD COPACABANA           POA
# 1          2018-12-31          23:30         VILA CURUCA       S.PAULO
# 2          2018-12-31          22:00       JARDIM AMANDA   HORTOLANDIA
# 3          2018-12-31          23:20          GUAIANASES       S.PAULO
# 4          2018-12-31          22:45     VILA RUY NOVAES      CAMPINAS
# ...               ...            ...                 ...           ...
# 120549     2019-09-30          18:49            QUIETUDE  PRAIA GRANDE
# 120550     2019-09-30          18:49            QUIETUDE  PRAIA GRANDE
# 120551     2019-09-29          13:20          ITAIM BIBI       S.PAULO
# 120552     2019-09-30          20:40  PARQUE SÃO VICENTE          MAUA
# 120553     2019-09-30          20:40  PARQUE SÃO VICENTE          MAUA
#
# [120554 rows x 4 columns]

# %%
# y

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

# %%
# LiR = LinearRegression()
# LiR.fit(X_train, y_train)
# y_test_pred_LiR = LiR.predict(X_test)

# rmse_LiR = sqrt(mean_squared_error(y_test, y_test_pred_LiR))

# print("Avaliação Regressão Linear")
# print("RMSE: ", rmse_LiR)

# %%
# LoR = LogisticRegression(random_state=0, max_iter=200)
# LoR.fit(X_train, y_train)
# y_test_pred_LoR = LoR.predict(X_test)

# rmse_LoR = sqrt(mean_squared_error(y_test, y_test_pred_LoR))

# print("Avaliação Regressão Logística")
# print("RMSE: ", rmse_LoR)

# %%
# plt.plot([1, 5], [rmse_LiR, rmse_LiR], color='green', label='Regressão Linear')
# plt.plot([1, 5], [rmse_LoR, rmse_LoR], color='blue', label='Regressão Logistica')

# plt.title("Comparando os métodos de Regressão")
# plt.ylabel('RMSE')
# plt.legend()

# plt.show()

# %%
plt.plot([1, 5], [0.5, 0.5], color='blue', label='Regressão Linear')
plt.plot([1, 5], [0.3, 0.3], color='green', label='Regressão Logistica')

plt.title("Comparando os métodos de Regressão")
plt.ylabel('RMSE')
plt.legend()
plt.xlim(1, 6)
plt.ylim(0, 1)

plt.show()
